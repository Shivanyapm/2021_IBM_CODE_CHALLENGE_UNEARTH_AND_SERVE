# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
ed = pd.read_csv('Education_updated1.csv')

# %%
ed.head()
# Out:
#          AadharID  Rationcard _Category  Monthly_Income _of _Family  Gender  \
# 0  1101 4101 3101                     0                        2500       1
# 1  1102 4101 3101                     0                        2300       1
# 2  1103 4101 3101                     0                        2000       1
# 3  1104 4101 3101                     0                        1800       1
# 4  1105 4101 3101                     0                        2000       1
#
#    Age   Number _of _employed _persons _in _family  \
# 0    18                                          0
# 1    20                                          0
# 2    10                                          0
# 3    13                                          0
# 4    14                                          0
#
#    Currently studying _or _not  Educationlevel  \
# 0                            0               2
# 1                            1               3
# 2                            0               1
# ...

# %%
ed.isna().sum()
# Out:
# AadharID                                     0
# Rationcard _Category                         0
# Monthly_Income _of _Family                   0
# Gender                                       0
# Age                                          0
# Number _of _employed _persons _in _family    0
# Currently studying _or _not                  0
# Educationlevel                               0
# Interested _to _continue _Education          0
# Qualified _for _Higher _Education            0
# Target                                       0
# dtype: int64

# %%
ed.shape
# Out:
# (1003, 11)

# %%
ed.describe(include =[np.number])
# Out:
#        Rationcard _Category  Monthly_Income _of _Family       Gender  \
# count            1003.00000                 1003.000000  1003.000000
# mean                0.47657                 8066.091725     0.499501
# std                 0.49970                 8045.861837     0.500249
# min                 0.00000                 1200.000000     0.000000
# 25%                 0.00000                 2200.000000     0.000000
# 50%                 0.00000                 2700.000000     0.000000
# 75%                 1.00000                13000.000000     1.000000
# max                 1.00000                35000.000000     1.000000
#
#               Age   Number _of _employed _persons _in _family  \
# count  1003.000000                                1003.000000
# mean     25.966102                                   0.523430
# std      15.365177                                   0.592871
# min       3.000000                                   0.000000
# ...

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(18,8))

ax1 = ed['Target'].value_counts().plot.pie( x="Education" ,y ='no.of needy persons', 
                   autopct = "%2.0f%%",labels=["Education","Needy persons"], startangle = 60,ax=ax1);
ax1.set(title = 'Percentage of needy persons in Dataset')
colors = ['#99ff99','#ffcc99']

ax2 = ed["Target"].value_counts().plot(kind="barh" ,ax =ax2,color=['green','red'])
for i,j in enumerate(ed["Target"].value_counts().values):
    ax2.text(0.5,i,j,fontsize=14)
ax2.set(title = 'No. of Needy persons in Data')
plt.show()

# %%
categorical_val = []
continous_val = []
for column in ed.columns:
    print('==============================')
    print(f"{column} : {ed[column].unique()}")
    if len(ed[column].unique()) <= 10:
        categorical_val.append(column)
    else:
        continous_val.append(column)
# Out:
# ...
# AadharID : ['1101 4101 3101' '1102 4101 3101' '1103 4101 3101' '1104 4101 3101'
#  '1105 4101 3101' '1106 4101 3101' '1107 4101 3101' '1108 4101 3101'
#  '1109 4101 3101' '1110 4101 3101' '1111 4101 3101' '1112 4101 3101'
#  '1113 4101 3101' '1114 4101 3101' '1115 4101 3101' '1116 4101 3101'
#  '1117 4101 3101' '1118 4101 3101' '1119 4101 3101' '1120 4101 3101'
#  '1121 4101 3101' '1122 4101 3101' '1123 4101 3101' '1124 4101 3101'
#  '1125 4101 3101' '1126 4101 3101' '1127 4101 3101' '1128 4101 3101'
#  '1129 4101 3101' '1130 4101 3101' '1131 4101 3101' '1132 4101 3101'
#  '1133 4101 3101' '1134 4101 3101' '1135 4101 3101' '1136 4101 3101'
#  '1137 4101 3101' '1138 4101 3101' '1139 4101 3101' '1140 4101 3101'
#  '1141 4101 3101' '1142 4101 3101' '1143 4101 3101' '1144 4101 3101'
#  '1145 4101 3101' '1146 4101 3101' '1147 4101 3101' '1148 4101 3101'
#  '1149 4101 3101' '1150 4101 3101' '1151 4101 3101' '1152 4101 3101'
# ...

# %%
categorical_val
# Out:
# ['Rationcard _Category',
#  'Gender',
#  'Number _of _employed _persons _in _family',
#  'Currently studying _or _not',
#  'Educationlevel',
#  'Interested _to _continue _Education',
#  'Qualified _for _Higher _Education ',
#  'Target']

# %%
plt.figure(figsize=(15, 15))

for i, column in enumerate(categorical_val, 1):
    plt.subplot(3, 3, i)
    ed[ed["Target"] == 0][column].hist(bins=35, color='green', label='Needy Persons = NO', alpha=0.6)
    ed[ed["Target"] == 1][column].hist(bins=35, color='blue', label='Needy persons = YES', alpha=0.6)
    plt.legend()
    plt.xlabel(column)

# %%
plt.figure(figsize=(15, 15))

for i, column in enumerate(continous_val, 1):
    plt.subplot(3, 2, i)
    ed[ed["Target"] == 0][column].hist(bins=35, color='red', label='Needy persons = NO', alpha=0.6)
    ed[ed["Target"] == 1][column].hist(bins=35, color='black', label='Needy persons = YES', alpha=0.6)
    plt.legend()
    plt.xlabel(column)

# %%
ed.head()
# Out:
#          AadharID  Rationcard _Category  Monthly_Income _of _Family  Gender  \
# 0  1101 4101 3101                     0                        2500       1
# 1  1102 4101 3101                     0                        2300       1
# 2  1103 4101 3101                     0                        2000       1
# 3  1104 4101 3101                     0                        1800       1
# 4  1105 4101 3101                     0                        2000       1
#
#    Age   Number _of _employed _persons _in _family  \
# 0    18                                          0
# 1    20                                          0
# 2    10                                          0
# 3    13                                          0
# 4    14                                          0
#
#    Currently studying _or _not  Educationlevel  \
# 0                            0               2
# 1                            1               3
# 2                            0               1
# ...

# %%
corr_matrix = ed.corr()
fig, ax = plt.subplots(figsize=(15, 15))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (10.5, -0.5)

# %%
ed.drop('Target', axis=1).corrwith(ed.Target).plot(kind='bar', grid=True, figsize=(12, 8),title="Correlation with target")
# Out:
# <AxesSubplot:title={'center':'Correlation with target'}>

# %%
categorical_val.remove('Target')
dataset = pd.get_dummies(ed, columns = categorical_val)

# %%
dataset.head()
# Out:
#          AadharID  Monthly_Income _of _Family  Age   Target  \
# 0  1101 4101 3101                        2500    18       1
# 1  1102 4101 3101                        2300    20       1
# 2  1103 4101 3101                        2000    10       1
# 3  1104 4101 3101                        1800    13       1
# 4  1105 4101 3101                        2000    14       1
#
#    Rationcard _Category_0  Rationcard _Category_1  Gender_0  Gender_1  \
# 0                       1                       0         0         1
# 1                       1                       0         0         1
# 2                       1                       0         0         1
# 3                       1                       0         0         1
# 4                       1                       0         0         1
#
#    Number _of _employed _persons _in _family_0  \
# 0                                            1
# 1                                            1
# ...

# %%
print(ed.columns)
print(dataset.columns)
# Out:
# Index(['AadharID', 'Rationcard _Category', 'Monthly_Income _of _Family',
#        'Gender', 'Age ', 'Number _of _employed _persons _in _family',
#        'Currently studying _or _not', 'Educationlevel',
#        'Interested _to _continue _Education',
#        'Qualified _for _Higher _Education ', 'Target'],
#       dtype='object')
# Index(['AadharID', 'Monthly_Income _of _Family', 'Age ', 'Target',
#        'Rationcard _Category_0', 'Rationcard _Category_1', 'Gender_0',
#        'Gender_1', 'Number _of _employed _persons _in _family_0',
#        'Number _of _employed _persons _in _family_1',
#        'Number _of _employed _persons _in _family_2',
#        'Currently studying _or _not_0', 'Currently studying _or _not_1',
#        'Educationlevel_0', 'Educationlevel_1', 'Educationlevel_2',
#        'Educationlevel_3', 'Interested _to _continue _Education_0',
#        'Interested _to _continue _Education_1',
#        'Qualified _for _Higher _Education _0',
# ...

# %%
ed = ed.drop(columns="AadharID")

# %%
ed.head()
# Out:
#    Rationcard _Category  Monthly_Income _of _Family  Gender  Age   \
# 0                     0                        2500       1    18
# 1                     0                        2300       1    20
# 2                     0                        2000       1    10
# 3                     0                        1800       1    13
# 4                     0                        2000       1    14
#
#    Number _of _employed _persons _in _family  Currently studying _or _not  \
# 0                                          0                            0
# 1                                          0                            1
# 2                                          0                            0
# 3                                          0                            1
# 4                                          0                            0
#
#    Educationlevel  Interested _to _continue _Education  \
# 0               2                                    1
# ...

# %%
ed.shape
# Out:
# (1003, 10)

# %%
from sklearn.model_selection import train_test_split

X = ed.drop('Target', axis=1)
y = ed.Target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=5)

# %%
print('Distribution of target variable in training set')
print(y_train.value_counts())

print('Distribution of target variable in test set')
print(y_test.value_counts())
# Out:
# Distribution of target variable in training set
# 1    379
# 0    323
# Name: Target, dtype: int64
# Distribution of target variable in test set
# 0    164
# 1    137
# Name: Target, dtype: int64

# %%
print('------------Training Set------------------')
print(X_train.shape)
print(y_train.shape)

print('------------Test Set------------------')
print(X_test.shape)
print(y_test.shape)
# Out:
# ------------Training Set------------------
# (702, 9)
# (702,)
# ------------Test Set------------------
# (301, 9)
# (301,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train[['Age ','Monthly_Income _of _Family']] = scaler.fit_transform(X_train[['Age ','Monthly_Income _of _Family']])
X_train.head()
# Out:
#      Rationcard _Category  Monthly_Income _of _Family  Gender      Age   \
# 132                     1                    0.215976       1  0.260274
# 944                     0                    0.026627       1  0.123288
# 784                     1                    0.112426       0  0.136986
# 681                     1                    0.408284       0  0.123288
# 66                      1                    0.201183       1  0.260274
#
#      Number _of _employed _persons _in _family  Currently studying _or _not  \
# 132                                          1                            0
# 944                                          0                            1
# 784                                          1                            1
# 681                                          1                            1
# 66                                           1                            0
#
#      Educationlevel  Interested _to _continue _Education  \
# ...

# %%
X_test[['Age ','Monthly_Income _of _Family']] = scaler.transform(X_test[['Age ','Monthly_Income _of _Family']])
X_test.head()
# Out:
#      Rationcard _Category  Monthly_Income _of _Family  Gender      Age   \
# 544                     0                    0.032544       1  0.205479
# 515                     0                    0.035503       1  0.273973
# 193                     0                    0.026627       1  0.219178
# 11                      0                    0.002959       0  0.164384
# 279                     0                    0.035503       1  0.575342
#
#      Number _of _employed _persons _in _family  Currently studying _or _not  \
# 544                                          0                            0
# 515                                          0                            0
# 193                                          0                            0
# 11                                           0                            0
# 279                                          0                            0
#
#      Educationlevel  Interested _to _continue _Education  \
# ...

# %%
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

model_xgb = XGBClassifier()
model_xgb.fit(X_train, y_train)
print('Accuracy of our XGB model on the training data is {:.2f} out of 1'.format(model_xgb.score(X_train, y_train)))
print('Accuracy of our XGB model on the test data is {:.2f} out of 1'.format(model_xgb.score(X_test, y_test)))

prediction = model_xgb.predict(X_test)
accuracy = accuracy_score(prediction,y_test)
cm = confusion_matrix(prediction,y_test)
prfs = precision_recall_fscore_support(prediction,y_test)
print('Accuracy: ',accuracy)
print('\n')
print('Confusion Matrix: ',cm)
print('\n')
print('Precision: ', prfs[0])
print('Recall:    ', prfs[1])
print('Fscore:    ', prfs[2])
print('Support:   ', prfs[3])
# Out:
# [11:33:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy of our XGB model on the training data is 0.99 out of 1
# Accuracy of our XGB model on the test data is 0.92 out of 1
# Accuracy:  0.9235880398671097
#
#
# Confusion Matrix:  [[151  10]
#  [ 13 127]]
#
#
# Precision:  [0.92073171 0.9270073 ]
# Recall:     [0.9378882  0.90714286]
# Fscore:     [0.92923077 0.91696751]
# Support:    [161 140]
